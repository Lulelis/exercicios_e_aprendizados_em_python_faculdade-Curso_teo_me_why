# %% [markdown]
# ## **3ª<u>Lista Prática: Laboratório Exercícios Repetição com Estrutura Condicional *For e For´s Aninhados*</u>**

# %% [markdown]
# > ### Refazer: 📑 **Desafio &**

# %% [markdown]
# ---

# %% [markdown]
# #### -> **AP05 - Roteiro Prático 5: Estruturas de Repetição com for**
#
# #### Neste roteiro você irá praticar o uso da estrutura de repetição for em diferentes tipos de problema.
#
# #### Os exercícios começam com repetições simples usando range() e evoluem para problemas que exigem acumuladores, condicionais dentro do loop, percorrer textos, validação de entradas e repetições aninhadas.
#
# #### Ao resolver as questões, procure identificar qual é o papel da variável controlada pelo for e quais informações precisam ser mantidas entre uma repetição e outra.
#
# #### Regras desta lista:
#
# - Utilize for como estrutura principal de repetição.
# - Utilize while somente quando o próprio enunciado solicitar validação de entrada.
# - Não utilize listas para armazenar todos os valores e processá-los depois.
# - Utilize nomes de variáveis significativos e mantenha a indentação correta.
# - Antes de programar, observe com atenção quais valores devem ser produzidos pelo range().
#
# #### Entrega das respostas:
#
# - Salve a solução de cada exercício em um arquivo Python (.py) e faça o upload do arquivo correspondente na respectiva questão do Canvas. Utilize nomes como exercicio_01.py, exercicio_02.py e assim por diante.

# %% [markdown]
# ### <u>**Parte 2 - Percorrendo textos com for**</u>
#
# #### O for não precisa trabalhar apenas com valores produzidos por range(). Ele também pode percorrer diretamente uma sequência, como uma string.
#
# #### Nesse caso, a variável do loop assume um caractere do texto a cada repetição:
#
# - for caractere in texto:
#     - ...
# #### Nos próximos exercícios, observe que não é necessário controlar manualmente a posição de cada caractere.

# %% [markdown]
# #### **Exercício 6 Análise dos caracteres de um texto**:
#
# #### Um sistema deseja analisar a composição de um texto informado pelo usuário.
#
# #### Escreva um programa que leia uma string e, percorrendo seus caracteres, determine:
#
# - quantas vogais existem;
# - quantas consoantes existem;
# - quantos dígitos numéricos existem;
# - quantos espaços existem.
#
# #### Considere como letras apenas os caracteres de A a Z e de a a z. Outros símbolos podem ser ignorados.

# %%
entrada = "lucas"
count_vogais = 0
nova_palavra = ""
for i in entrada:
    print(i)
    if i =="a" or i=="e" or i =="i" or  i=="o" or i =="u":
        count_vogais +=1
    else:
        nova_palavra +=i

print(nova_palavra)
print(count_vogais)
# Out:
# l
# u
# c
# a
# s
# lcs
# 2

# %%
def analise_textual(entrada):
    count_vogais  =0
    count_consoantes = 0
    count_num = 0
    count_espacos = 0
    entrada = entrada.lower()
    for i in entrada:
        if i in ('aeiou'):
            count_vogais +=1
        elif i not in("aeiou") and i not in ("0123456789") and i not in (" ", ""):
            count_consoantes +=1
        if i in ('0123456789'):
            count_num+=1
        if i in (" ", ""):
            count_espacos +=1
    return (f'Quantidade Vogais: {count_vogais}\nQuantidade Consoantes: {count_consoantes}\nQuantidade espaços: {count_espacos}\nQuantidade Números: {count_num}')

# %%
palavra = input("Digite a Palavra para se analisar ela textualmente: ")
print(analise_textual(palavra))
# Out:
# Quantidade Vogais: 2
# Quantidade Consoantes: 10
# Quantidade espaços: 2
# Quantidade Números: 2

# %% [markdown]
# ####  **Exercício 7 <u>Extração da parte numérica de um identificador**</u>
#
# #### Um sistema recebe um identificador que pode conter letras, números, espaços e outros símbolos. Para uma etapa posterior do processamento, interessa apenas a parte numérica desse identificador.
#
# #### Escreva um programa que leia o identificador como texto e construa uma nova string contendo somente os dígitos, preservando a ordem em que eles aparecem.
#
# #### Ao final, exiba a parte numérica encontrada e a quantidade de dígitos utilizados.
#
# #### - Exemplo:
#
# - Entrada: AB-12 C9
# - Parte numérica: 129

# %%
def extrai_numero(entrada):
    parte_num  = ""
    qtd_num = 0
    for i in range(len(entrada)):
        if entrada[i] in ('0123456789'):
            parte_num += entrada[i]
            qtd_num+=1
    if qtd_num ==0:
        print("Entrada não tem número!")
    else:
        print(f"Parte Numérica: {parte_num}\nQuantidade Numérica: {qtd_num}")

# %%
entrada = input("Digite a entrada para se verificar se tem número ou não: ")
extrai_numero(entrada)
# Out:
# Parte Numérica: 4579
# Quantidade Numérica: 4

# %% [markdown]
# ### <u>**Parte 3 - Repetições aninhadas** </u>
#
# #### Alguns problemas possuem dois níveis de repetição. Por exemplo, podemos repetir um processamento para várias máquinas e, para cada máquina, repetir a leitura de vários turnos.
#
# #### Nesses casos, um for pode aparecer dentro de outro:
#
# - for grupo in ...:
#     - prepara informações do grupo
#
#     - for elemento in ...:
#         - processa cada elemento
#
#     - finaliza informações do grupo
#
# #### Preste atenção especial às variáveis que precisam ser reiniciadas a cada novo grupo e às que devem manter informações globais.

# %% [markdown]
# #### **Exercício 9** Produção de máquinas por turno
#
# #### Uma fábrica possui M máquinas. Para cada máquina, são registradas as quantidades de peças produzidas em T turnos.
#
# #### Escreva um programa que leia M e T. Depois, para cada máquina, leia a produção de todos os seus turnos.
#
# #### O programa deve:
#
#
# - mostrar o total produzido por cada máquina;
# - mostrar a média de produção por turno de cada máquina;
# - ao final, mostrar o total produzido por toda a fábrica;
# - informar qual máquina teve o maior total de produção.
# - Considere que M e T são positivos e que as quantidades produzidas são valores inteiros não negativos.

# %%
def maquinas_por_turno(maquinas):
    maquina_maior_total =""
    maior_producao = float("-inf")
    soma_producao_geral = 0
    for i in range(1, maquinas+1):
        soma_producao = 0
        qtd_turnos = 0
        turnos = int(input(f"Digite quantos turnos foram realizados por essa máquina:{i}"))
        while turnos < 0:
            print("Não existe turnos negativos!")
            turnos = int(input(f"Digite quantos turnos foram realizados por essa máquina:{i}"))
        for j in range(1, turnos+1):
            pecas = int(input(f"Digite a quantidade peças produzidas nesse {j}º Turno: "))
            while pecas <0:
                print("Não existe quantidade de peças produzidas negativas!")
                pecas = int(input(f"Digite a quantidade peças produzidas nesse {j}º Turno: "))
            soma_producao_geral += pecas
            soma_producao += pecas
        print(f"Total produzido pela máquina {i}: {soma_producao}")
        media_producao = soma_producao/turnos
        print(f"Média de produção máquina: {i}: {media_producao}")
        if soma_producao > maior_producao:
            maior_producao = soma_producao
            maquina_maior_total =i
    if maior_producao <=0:
        return print('Nessa máquina foram produzidas totais de 0!')
    else:
        return (f'Máquina com maior total produzido: {maquina_maior_total}\nMaior Produção obtida por essa máquina: {maior_producao}\n Total Geral Produzido na Fábrica: {soma_producao_geral}')

# %% [markdown]
# ### Como testar maior produção das máquinas SEM UTILIZAR LISTAS!

# %%
maquinas = int(input("Informea  quantidade de máquina gerais na fábrica: "))
while maquinas <0:
    print("Não existe total negativo!")
    maquinas = int(input("Informea  quantidade de máquina gerais na fábrica: "))
print(maquinas_por_turno(maquinas))
# Out:
# Total produzido pela máquina 1: 37
# Média de produção máquina: 1: 12.333333333333334
# Total produzido pela máquina 2: 96
# Média de produção máquina: 2: 48.0
# Total produzido pela máquina 3: 353
# Média de produção máquina: 3: 117.66666666666667
# Total produzido pela máquina 4: 100
# Média de produção máquina: 4: 100.0
# Total produzido pela máquina 5: 745
# Média de produção máquina: 5: 124.16666666666667
# Máquina com maior total produzido: 5
# Maior Produção obtida por essa máquina: 745
#  Total Geral Produzido na Fábrica: 1331
