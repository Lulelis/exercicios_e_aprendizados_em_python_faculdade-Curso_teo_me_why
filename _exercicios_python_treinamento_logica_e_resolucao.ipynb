# %% [markdown]
# ##  🐍 **Exercícios em Python: Beecrowd/Gustavo_Guanabara (Fora de ordem)** apenas para exercitar a lógica 📚

# %% [markdown]
# ### Exercício 30- Lista_2:PUC

# %%
pip install pygame
# Out:
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/10.6 MB 11.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.5/10.6 MB 11.7 MB/s eta 0:00:01
#    ------------------------- -------------- 6.8/10.6 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.6 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 10.4 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
